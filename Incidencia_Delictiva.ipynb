# %% [markdown]
# # Encuesta Nacional de Victimización y Percepción sobre la Seguridad Pública (ENVIPE) 2024
#
# ![image.png](data:image/png;base64,...)
#
#
# La Encuesta Nacional de Victimización y Percepción sobre Seguridad Pública (ENVIPE) 2024 es la décima cuarta entrega de la serie estadística generada por el Subsistema Nacional de Información de Gobierno, Seguridad Pública e Impartición de Justicia (SNIGSPIJ), coordinada por el Instituto Nacional de Estadística y Geografía (INEGI). Con este proyecto se da continuidad a las temáticas abordadas en las ediciones anteriores de esta encuesta, cuyos resultados han sido declarados Información de Interés Nacional por la Junta de Gobierno del INEGI.
#
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Para el diseño de esta serie estadística se retomaron las mejores prácticas en materia de encuestas de victimización, específicamente las recomendaciones de la Organización de las Naciones Unidas (ONU); asimismo se retomaron las propuestas de autoridades de seguridad pública y justicia, y de expertos académicos de México, siendo también muy valiosa en su concepción la experiencia del INEGI en el levantamiento de encuestas vinculadas con la seguridad y justicia, experiencia que se remonta a finales de los ochenta.
#
#
# En virtud de su importancia, desde diciembre de 2011 la ENVIPE fue declarada información de interés nacional por la Junta de Gobierno del INEGI, lo cual significa que su uso es obligatorio para la Federación, los estados, la Ciudad de México y los municipios, por lo que su publicación es en forma regular y periódica.
#
#
# La ENVIPE 2024 es el décimo cuarto ejercicio de esta serie, a la cual anteceden los ejercicios anuales realizados de manera ininterrumpida de 2011 a 2023.
#
#
# ![image.png](data:image/png;base64,...)
#
#
# **Objetivo: Obtener información con representatividad a nivel nacional y estatal que permita realizar estimaciones de la prevalencia delictiva que afectó a los hogares durante 2023, los niveles de incidencia delictiva y cifra negra. Asimismo, se busca obtener información sobre la percepción de la seguridad pública, así como el desempeño de las instituciones a cargo de la seguridad pública y la justicia. También se recaba información sobre las características del delito, el contexto de la victimización y el impacto económico y social del delito. Esto con el fin de proveer información al público en general y generar elementos para la toma de decisiones de política pública en estas materias.**
#
#
# ![image.png](data:image/png;base64,...)
#
# [Consultar Fuente](https://www.inegi.org.mx/programas/envipe/2024/#datos_abiertos)

# %% [markdown]
# ### Periodicidad
#
# - Anual
#
# ### Población objetivo
#
# - Personas de 18 años y más.
#
# ### Cobertura temática
# - Tipo de vivienda.
# - Hogares y residentes en la vivienda.
# - Integrantes del hogar y características sociodemográficas.
# - Percepción sobre seguridad pública.
#   - Percepción de seguridad en el entorno.
#   - Sensación de inseguridad por temor a ser víctima del delito.
#   - Atestiguación de conductas antisociales y delictivas.
#   - Prevención y protección ante el delito.
#   - Cohesión social.
# - Desempeño institucional.
#   - Percepción del desempeño de las autoridades.
#   - Actitudes hacia la policía y el sistema de justicia penal.
# - Victimización.
#   - Incidentes delictivos en el hogar.
#     - Robo total de vehículo (automóvil, camioneta o camión).
#     - Robo de accesorios, refacciones o herramientas de vehículos (automóvil, camioneta o camión).
#     - Pinta de barda o grafiti en su casa, daños intencionales a vehículo, y otro tipo de vandalismo.
#     - Robo o intento de robo a casa habitación.
#   - Incidentes delictivos de alto impacto en el hogar.
#     - Secuestro.
#     - Desaparición forzada.
#     - Homicidio.
#   - Experiencia de victimización personal.
#     - Robo o asalto en la calle o en transporte público.
#     - Robo en forma distinta al anterior.
#     - Fraude bancario.
#     - Fraude al consumidor.
#     - Extorsión.
#     - Amenazas.
#     - Lesiones.
#     - Secuestro.
#     - Delitos contra la libertad sexual, la seguridad sexual o el normal desarrollo psicosexual.
#       - Hostigamiento o intimidación.
#       - Manoseo.
#       - Exhibicionismo.
#       - Intento de violación.
#       - Violación sexual.
#     - Otros delitos.
#   - Contexto de victimización.
#     - Caracterización del contexto del delito.
#     - Características de los delincuentes.
#     - Condición de portación de armas.
#     - Condición de agresión y lesiones a causa del delito.
#   - Denuncia ante el Ministerio Público o Fiscalía Estatal.
#   - Experiencia al denunciar.
#   - Daños y costos de la victimización.
#   - Seguimiento y detalles de la victimización.
#
#
#   ### Clasificadores utilizados
#
# - Clasificación Internacional de Delitos con Fines Estadísticos emitida por la Oficina de las Naciones Unidas contra la Droga y el Delito, 2015.
# - Norma Técnica para la Clasificación Nacional de Delitos para Fines Estadísticos, 2018.
# - Catálogo Único de Claves de Áreas Geoestadísticas Estatales, Municipales y Localidades, 2020.
#
#
# ### Instrumentos de captación
#
# - Cuestionario principal.
# - Módulo sobre victimización.
#
# ### Cobertura temporal
#
# - 2023 para victimización y 2024 para percepción de la seguridad pública y desempeño de las autoridades.
#
# ### Cobertura geográfica
#
# La encuesta está diseñada para dar resultados a los siguientes niveles de desagregación:
# - Nacional.
#   - Urbano.
#   - Rural.
# - Entidad federativa.
# - 34 áreas urbanas de interés, con la Ciudad de México dividida en cuatro regiones geográficas (norte, sur, oriente y poniente).
#
#
# ### Tamaño de la muestra (de la ENVIPE completa)
#
# - 102 287 viviendas.
#
# ### Periodo de captación
#
# Del 04 de marzo al 26 de abril de 2024.
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

data=pd.read_csv('/content/drive/MyDrive/Incidencia_Delictiva_2024/tmod_vic_envipe2024 - delitos/conjunto_de_datos/conjunto_de_datos_tmod_vic_envipe2024.csv')

data
# Out:
#            ID_VIV         ID_HOG            ID_PER                 ID_DEL  \
# 0       101774.01  0101774.01.01  0101774.01.01.01  0101774.01.01.01.07.1
# 1       102228.18  0102228.18.01  0102228.18.01.04  0102228.18.01.04.02.3
# 2       101074.04  0101074.04.01  0101074.04.01.04  0101074.04.01.04.07.2
# 3       101763.03  0101763.03.01  0101763.03.01.01  0101763.03.01.01.05.1
# 4       100012.03  0100012.03.01  0100012.03.01.01  0100012.03.01.01.03.1
# ...           ...            ...               ...                    ...
# 37609  2806779.05  2806779.05.01  2806779.05.01.02  2806779.05.01.02.03.1
# 37610  1404163.05  1404163.05.01  1404163.05.01.02  1404163.05.01.02.03.2
# 37611  3008473.08  3008473.08.01  3008473.08.01.03  3008473.08.01.03.04.1
# 37612  2806778.02  2806778.02.01  2806778.02.01.04  2806778.02.01.04.03.2
# 37613  2202506.17  2202506.17.01  2202506.17.01.01  2202506.17.01.01.07.1
#
#            UPM  VIV_SEL  HOGAR  ND_TIPO  TD_TIPO  BPCOD  ...  BP6_1 BP6_2  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37614 entries, 0 to 37613
# Columns: 129 entries, ID_VIV to UPM_DIS
# dtypes: float64(103), int64(21), object(5)
# memory usage: 37.0+ MB

# %% [markdown]
# ### Mapeo de las columnas

# %%
column_mapping = {
    "ID_VIV": "Identificador de vivienda seleccionada",
    "ID_HOG": "Identificador del hogar seleccionado",
    "ID_PER": "Identificador de la persona",
    "ID_DEL": "Identificador del delito",
    "UPM": "Control de vivienda (UPM)",
    "VIV_SEL": "Vivienda seleccionada",
    "HOGAR": "Control del hogar",
    "ND_TIPO": "Número de delito por tipo",
    "TD_TIPO": "Total de delitos por tipo",
    "BPCOD": "Códigos para delitos",
    "R_SEL": "Número de renglón de la persona seleccionada",
    "RESUL_H": "Resultado de la visita al hogar",
    "SEXO": "Sexo",
    "EDAD": "Edad",
    "AREAM_OCU": "Área urbana de interés de ocurrencia del delito",
    "BP1_1": "Mes de ocurrencia del delito",
    "BP1_2C": "Entidad de ocurrencia del delito",
    "BP1_3C": "Municipio de ocurrencia del delito",
    "BP1_4": "Hora aproximada de ocurrencia del delito",
    "BP1_5": "Lugar de ocurrencia del delito",
    "BP1_6": "Presencia de la víctima durante la ocurrencia del delito",
    "BP1_7": "Condición de observar el delito mientras ocurría",
    "BP1_8": "Condición de estar acompañada la víctima",
    "BP1_9": "Número de delincuentes que participaron",
    "BP1_10_1": "Delincuentes hombres",
    "BP1_10_2": "Delincuentes mujeres",
    "BP1_10_9": "Sexo de los delincuentes no especificado",
    "BP1_11": "Edad aproximada de los delincuentes",
    "BP1_12_1": "Delincuentes desconocidos",
    "BP1_12_2": "Delincuentes conocidos de vista solamente",
    "BP1_12_3": "Delincuentes conocidos de poco trato",
    "BP1_12_4": "Delincuentes conocidos cercanos",
    "BP1_12_5": "Delincuentes familiares",
    "BP1_12_9": "Relación con los delincuentes no especificada",
    "BP1_13": "Reconocimiento de los delincuentes",
    "BP1_14_1": "Delincuentes bajo los efectos de alguna droga",
    "BP1_14_2": "Delincuentes bajo los efectos del alcohol",
    "BP1_14_3": "Delincuentes bajo otros efectos",
    "BP1_14_4": "Delincuentes que no se perciben bajo ningún efecto de drogas, alcohol u otro",
    "BP1_14_9": "Estado psicofísico de los delincuentes no especificado",
    "BP1_15": "Portación de armas",
    "BP1_16_1": "Portación de arma de fuego",
    "BP1_16_2": "Portación de arma blanca",
    "BP1_16_3": "Portación de objeto contundente",
    "BP1_16_4": "Portación de otro tipo de arma",
    "BP1_16_9": "Tipo de arma utilizada no especificado",
    "BP1_17": "Lesión física con el arma",
    "BP1_18": "Otro tipo de violencia física",
    "BP1_19_1": "Moretones",
    "BP1_19_2": "Cortadas",
    "BP1_19_3": "Dislocaciones",
    "BP1_19_4": "Fracturas",
    "BP1_19_5": "Quemaduras",
    "BP1_19_6": "Pérdida del conocimiento",
    "BP1_19_7": "Herida de bala",
    "BP1_19_8": "Otro tipo de lesión física",
    "BP1_20": "Denuncia ante el MP o Fiscalía Estatal",
    "BP1_21": "Denuncia ante el MP o Fiscalía Estatal por otro integrante del hogar",
    "BP1_22": "Conocimiento del proceso de denuncia",
    "BP1_23": "Razón principal de la no denuncia",
    "BP1_24": "Inicio de carpeta de investigación",
    "BP1_25": "Estatus de la carpeta de investigación",
    "BP1_26": "Razón principal de no inicio de carpeta de investigación",
    "BP1_27": "Tiempo invertido al denunciar ante el MP",
    "BP1_28": "Razón principal de denuncia ante el MP",
    "BP1_29": "Trato recibido en el MP al denunciar",
    "BP1_30": "Reporte del delito ante otra instancia o autoridad",
    "BP1_31_01": "Reporte ante Autoridad Comunal o Ejidal",
    "BP1_31_02": "Reporte ante Autoridad / Policía Municipal",
    "BP1_31_03": "Reporte ante Consejos Municipales Ciudadanos o similares",
    "BP1_31_04": "Reporte ante Policía Estatal",
    "BP1_31_05": "Reporte ante autoridad Guardia Nacional",
    "BP1_31_06": "Reporte ante autoridad Militar o Naval",
    "BP1_31_07": "Reporte ante Fiscalía General de la República (FGR)",
    "BP1_31_08": "Reporte ante otra instancia o autoridad",
    "BP1_31_99": "Reporte ante otra instancia o autoridad no especificado",
    "BP1_32_1": "Denuncia telefónica",
    "BP1_32_2": "Denuncia a través de internet",
    "BP1_32_3": "Denuncia a través de correo electrónico",
    "BP1_32_4": "Denuncia a través de mensaje de texto",
    "BP1_32_5": "Denuncia a través de otros medios negada",
    "BP1_32_9": "Denuncia a través otros medios no especificada",
    "BP1_33": "Daño principal sufrido por el delito",
    "BP1_34": "Pérdidas económicas a consecuencia del delito",
    "BP1_35": "Gastos a consecuencia del daño en la salud",
    "BP1_36_01": "Servicio de denuncia anónima",
    "BP1_36_02": "Servicio de información sobre el proceso de la AP o CI",
    "BP1_36_03": "Servicio de información sobre derechos como víctima",
    "BP1_36_04": "Servicio de asesoría jurídica",
    "BP1_36_05": "Servicio de ayuda asistencial",
    "BP1_36_06": "Servicio de atención psicológica",
    "BP1_36_07": "Servicio de atención médica",
    "BP1_36_08": "Servicio de reparación del daño",
    "BP1_36_09": "Servicio de protección",
    "BP1_36_10": "Otros servicios que deban ofrecer las autoridades",
    "BP1_36_11": "Ningún servicio que deban proporcionar las autoridades",
    "BP1_36_99": "Servicios que deban ofrecer las autoridades no especificado",
    "BP2_1": "Vehículo robado asegurado",
    "BP3_1_01": "Robo de cableado o instalación de cobre",
    "BP3_1_02": "Robo de mobiliario",
    "BP3_1_03": "Robo de equipo electrónico",
    "BP3_1_04": "Robo de electrodomésticos",
    "BP3_1_05": "Robo de bolsa, maleta, portafolio",
    "BP3_1_06": "Robo de joyas, reloj",
    "BP3_1_07": "Robo de dinero, tarjetas de crédito, cheques",
    "BP3_1_08": "Robo de identificación o documentos",
    "BP3_1_09": "Robo de teléfono celular",
    "BP3_1_10": "Robo de bicicleta",
    "BP3_1_11": "Robo de otro objeto",
    "BP3_1_12": "Nada robado",
    "BP3_1_99": "Robo de objeto no especificado",
    "BP3_2": "Presencia de algún(a) integrante del hogar al momento del robo a casa-habitación",
    "BP4_1": "Tipo de fraude",
    "BP5_1": "Tipo de extorsión",
    "BP5_2_1": "Solicitaron dinero",
    "BP5_2_2": "Solicitaron tarjetas prepagadas de teléfono celular",
    "BP5_2_3": "Solicitaron otra cosa",
    "BP5_2_4": "No alcanzaron a solicitar nada",
    "BP5_3": "Entrega de lo exigido por el(la) extorsionador(a)",
    "BP6_1": "Tipo de secuestro (según clasificación de secuestro, categoría tentativa o categoría consumado)",
    "BP6_2": "Entrega de lo exigido por los secuestradores",
}

data = data.rename(columns=column_mapping)

data.head()
# Out:
#    Identificador de vivienda seleccionada  \
# 0                               101774.01
# 1                               102228.18
# 2                               101074.04
# 3                               101763.03
# 4                               100012.03
#
#   Identificador del hogar seleccionado Identificador de la persona  \
# 0                        0101774.01.01            0101774.01.01.01
# 1                        0102228.18.01            0102228.18.01.04
# 2                        0101074.04.01            0101074.04.01.04
# 3                        0101763.03.01            0101763.03.01.01
# 4                        0100012.03.01            0100012.03.01.01
#
#   Identificador del delito  Control de vivienda (UPM)  Vivienda seleccionada  \
# 0    0101774.01.01.01.07.1                     101774                      1
# 1    0102228.18.01.04.02.3                     102228                     18
# ...

# %%
data.describe()
# Out:
#        Identificador de vivienda seleccionada  Control de vivienda (UPM)  \
# count                            3.761400e+04               3.761400e+04
# mean                             1.595468e+06               1.595468e+06
# std                              9.018184e+05               9.018184e+05
# min                              1.000050e+05               1.000050e+05
# 25%                              9.024255e+05               9.024255e+05
# 50%                              1.522739e+06               1.522739e+06
# 75%                              2.302846e+06               2.302846e+06
# max                              3.260800e+06               3.260800e+06
#
#        Vivienda seleccionada  Control del hogar  Número de delito por tipo  \
# count           37614.000000       37614.000000               37614.000000
# mean                5.306694           1.018929                   1.273994
# std                 4.880106           0.156780                   0.660765
# ...
